# %% [markdown]
# # Task 1
#
# FCFs for $H_2$ - $H_2^+$ using the harmonic oscillator approximation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - Calculate transitions between different excitations

# %%
from FCF_helper import FCFSpec
import pandas as pd

fcfspec = FCFSpec(n_0=9, n_p=9)
spectrum = fcfspec.spectrum_analysis()

spectrum
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.23378957e+05],
#        [0.00000000e+00, 1.00000000e+00, 2.95139079e+00, 1.25700957e+05],
#        [0.00000000e+00, 2.00000000e+00, 3.49048846e+00, 1.28022957e+05],
#        [0.00000000e+00, 3.00000000e+00, 2.01446220e+00, 1.30344957e+05],
#        [0.00000000e+00, 4.00000000e+00, 5.16711333e-01, 1.32666957e+05],
#        [0.00000000e+00, 5.00000000e+00, 2.55047939e-02, 1.34988957e+05],
#        [0.00000000e+00, 6.00000000e+00, 8.26500159e-03, 1.37310957e+05],
#        [0.00000000e+00, 7.00000000e+00, 1.09734335e-02, 1.39632957e+05],
#        [0.00000000e+00, 8.00000000e+00, 1.39346082e-03, 1.41954957e+05],
#        [0.00000000e+00, 9.00000000e+00, 8.39894919e-05, 1.44276957e+05],
#        [1.00000000e+00, 0.00000000e+00, 1.55717551e+00, 1.18977957e+05],
#        [1.00000000e+00, 1.00000000e+00, 1.42278254e+00, 1.21299957e+05],
#        [1.00000000e+00, 2.00000000e+00, 4.36585159e-04, 1.23621957e+05],
# ...

# %%
df = pd.DataFrame(spectrum, columns=["n_0", 'n_p', 'FCF', 'Ep-E0'])
df.set_index('n_p')
for i in range(10):
    this_df = df.iloc[i*10:(i+1)*10]
    ax = this_df.plot(x='n_p', y='FCF', label=f'FCF (n_0 = {i})')
    ax.set_ylabel('FCF')
    ax.set_xlabel('n_p')

# %%
this_df = df.iloc[0:10]
ax = this_df.plot(x='n_p', y='FCF', label=f'FCF (n_0 = 0)')
ax.set_ylabel('FCF')
this_df = df[df['n_p'] == 0]
this_df['n_0'] *= -1
this_df.plot(x='n_0', y='FCF', label=f'FCF (n_p = 0)', ax=ax)

ax.set_xlabel('n_0 | n_p')
# Out:
# /Users/shukob/opt/anaconda3/envs/CohortProject_2020_37/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# Text(0.5, 0, 'n_0 | n_p')
